# %%
df_pyspark = spark.read.csv('file:/Workspace/Users/vaishnavikumbhakarna467@gmail.com/practice_pyspark/test3.csv',header=True,inferSchema=True)
display(df_pyspark)

# %%
df_one = df_pyspark.filter(df_pyspark['Salary']>50000)
display(df_one)

# %%
df_two = df_pyspark.filter(df_pyspark['Age']<=28)
display(df_two)

# %%
df_three = df_pyspark.filter((df_pyspark['Experience'] <= 2) & (df_pyspark['Age'] >=25))
display(df_three)

# %%
df_three = df_pyspark.filter((df_pyspark['Experience'] >= 2) | (df_pyspark['Age'] >=25))
display(df_three)

# %%
df_four = df_pyspark.filter(~(df_pyspark['Age'] > 30))
display(df_four)
