# %%
# pip install pyspark - to install pyspark in the system
import pyspark

# %%
import pandas as pd
pd.read_csv('test1.csv')

# %%
# To start the sparksession
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Practice").getOrCreate()
# This will display the sparksession details like <pyspark.sql.connect.session.SparkSession at 0xff77a0181e20>
display(spark)

# %%
# reading the dataset and creating the dataframe 
df_pyspark = spark.read.csv('test1.csv')
# the above command won't execute as spark.read function needs absolute address or path of a file
df_pyspark = spark.read.csv('file:/Workspace/Users/vaishnavikumbhakarna467@gmail.com/practice_pyspark/test1.csv')
df_pyspark
print("DISPLAY")
display(df_pyspark)
print("SHOW")
df_pyspark.show()
print("PRINTSCHEMA")
df_pyspark.printSchema()

# %%
df_pyspark = spark.read.option('header','true').csv('file:/Workspace/Users/vaishnavikumbhakarna467@gmail.com/practice_pyspark/test1.csv')
df_pyspark.show()

# %%
display(df_pyspark)
display(df_pyspark.head(3))
# df_pyspark.head(3)
df_pyspark.printSchema()
